# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy
from scipy import stats

# %%
migVSmoney=pd.read_csv("Raw_Data/MigrationVSMoney31_continents.csv")
migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  \
# 0  Afghanistan       2000.0          9.515139
# 1  Afghanistan       2001.0          7.586477
# 2  Afghanistan       2002.0         11.206747
# 3  Afghanistan       2003.0         29.388571
# 4  Afghanistan       2004.0         50.550219
#
#    Average of emigration over all OECD countries Continent
# 0                                       0.000824      ASIA
# 1                                       0.000947      ASIA
# 2                                       0.000689      ASIA
# 3                                       0.000587      ASIA
# 4                                       0.000550      ASIA

# %%
migVSmoney=migVSmoney.sort_values(by="3yrAverage Money")
migVSmoney.head()
# Out:
#                 Recipient  Report Year  3yrAverage Money  \
# 1216     Marshall Islands       2006.0       -440.384615
# 69    Antigua and Barbuda       2005.0       -196.979144
# 68    Antigua and Barbuda       2004.0       -181.707754
# 67    Antigua and Barbuda       2003.0       -172.884546
# 1219     Marshall Islands       2009.0       -103.782051
#
#       Average of emigration over all OECD countries   Continent
# 1216                                       0.001750     OCEANIA
# 69                                         0.005315  CARRIBEANS
# 68                                         0.005057  CARRIBEANS
# 67                                         0.004000  CARRIBEANS
# 1219                                       0.001558     OCEANIA

# %%
migVSmoney=migVSmoney[migVSmoney["Continent"]=="AFRICA"]
migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  \
# 47     Algeria       2015.0         -5.665645
# 1117     Libya       2000.0          1.196304
# 46     Algeria       2014.0          1.310014
# 1457   Nigeria       2000.0          1.824997
# 1458   Nigeria       2001.0          1.849256
#
#       Average of emigration over all OECD countries Continent
# 47                                         0.001128    AFRICA
# 1117                                       0.000735    AFRICA
# 46                                         0.001047    AFRICA
# 1457                                       0.000187    AFRICA
# 1458                                       0.000151    AFRICA

# %%
migVSmoney=migVSmoney.rename(columns={"Average of emigration over all OECD countries":"3yrAverage Migration"})
migVSmoney
# Out:
#                              Recipient  Report Year  3yrAverage Money  \
# 47                             Algeria       2015.0         -5.665645
# 1117                             Libya       2000.0          1.196304
# 46                             Algeria       2014.0          1.310014
# 1457                           Nigeria       2000.0          1.824997
# 1458                           Nigeria       2001.0          1.849256
# 1459                           Nigeria       2002.0          1.870923
# 45                             Algeria       2013.0          2.642346
# 544   Democratic Republic of the Congo       2001.0          3.440108
# 33                             Algeria       2001.0          3.784084
# 545   Democratic Republic of the Congo       2002.0          4.176207
# 543   Democratic Republic of the Congo       2000.0          4.229398
# 1829                             Sudan       2000.0          8.192723
# 1831                             Sudan       2002.0          8.827592
# 1830                             Sudan       2001.0          9.153017
# 1832                             Sudan       2003.0          9.279998
# 687                           Ethiopia       2000.0         11.365422
# 1781                           Somalia       2000.0         11.380113
# 688                           Ethiopia       2001.0         11.442808
# 1460                           Nigeria       2003.0         11.491756
# 1118                             Libya       2008.0         11.647265
# 32                             Algeria       2000.0         11.657234
# 1782                           Somalia       2001.0         11.740851
# 689                           Ethiopia       2002.0         13.078282
# 1961                              Togo       2004.0         13.385895
# 546   Democratic Republic of the Congo       2003.0         13.397510
# 1833                             Sudan       2004.0         13.567326
# 1783                           Somalia       2002.0         13.783981
# 1681              0.006649    AFRICA
# 327               0.009293    AFRICA
# 323               0.015478    AFRICA
# 1740              0.001685    AFRICA
# 326               0.009464    AFRICA
# 324               0.012885    AFRICA
# 325               0.011906    AFRICA
# 1741              0.001457    AFRICA
# 1742              0.001441    AFRICA
#
# [807 rows x 5 columns]

# %%
migVSmoneyQ=migVSmoney.quantile([.05, .95])
migVSmoneyQ
# Out:
#       Report Year  3yrAverage Money  3yrAverage Migration
# 0.05       2000.0         16.022198              0.000036
# 0.95       2015.0        294.631101              0.004675

# %%
MigrationUPboundary=migVSmoneyQ.iloc[1][2]
MigrationLOWboundary=migVSmoneyQ.iloc[0][2]
MoneyUPboundary=migVSmoneyQ.iloc[1][1]
MoneyLOWboundary=migVSmoneyQ.iloc[0][1]
print(MigrationUPboundary,MigrationLOWboundary)
print(MoneyUPboundary,MoneyLOWboundary)
# Out:
# 0.00467531747958 3.59047085289e-05
# 294.631101339 16.0221983762

# %%
df=migVSmoney
len(migVSmoney)
# Out:
# 807

# %%
migVSmoneyQ = migVSmoney[(migVSmoney["3yrAverage Money"] > MoneyLOWboundary) & (migVSmoney["3yrAverage Money"] < MoneyUPboundary) ]
df = migVSmoneyQ[(migVSmoneyQ["3yrAverage Migration"] > MigrationLOWboundary) & (migVSmoneyQ["3yrAverage Migration"] < MigrationUPboundary)]
len(df)
# Out:
# 664

# %%
# define the data/predictors as the pre-set feature names  
#df = pd.DataFrame(df, columns=["Average Sum of Money"])

# Put the target (housing value -- MEDV) in another DataFrame
#target = pd.DataFrame(df, columns=["Average of emigration over all OECD countries"])

# %%
#Shapiro-Wilk
x = df['3yrAverage Money']
y = df["3yrAverage Migration"]

shapiro_results = scipy.stats.shapiro(x)

print(shapiro_results)
shapiro_results = scipy.stats.shapiro(y)

print(shapiro_results)
# Out:
# (0.833170473575592, 9.282175598411372e-26)
# (0.7747172117233276, 3.24632344013482e-29)

# %%
x = df['3yrAverage Money']
y = df["3yrAverage Migration"]

levene_results = scipy.stats.levene(x,y)

print(levene_results)
# Out:
# LeveneResult(statistic=534.35795382290428, pvalue=1.3017497795349405e-99)

# %%
import statsmodels.api as sm

X = df['3yrAverage Money']
y = df["3yrAverage Migration"]

X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     3yrAverage Migration   R-squared:                       0.052
# Model:                              OLS   Adj. R-squared:                  0.051
# Method:                   Least Squares   F-statistic:                     36.39
# Date:                  Sun, 12 Nov 2017   Prob (F-statistic):           2.69e-09
# Time:                          18:32:48   Log-Likelihood:                 3753.5
# No. Observations:                   664   AIC:                            -7503.
# Df Residuals:                       662   BIC:                            -7494.
# Df Model:                             1
# Covariance Type:              nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0005   5.86e-05      8.136      0.000       0.000       0.001
# 3yrAverage Money  3.836e-06   6.36e-07      6.033      0.000    2.59e-06    5.08e-06
# ==============================================================================
# Omnibus:                      251.440   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              797.072
# Skew:                           1.855   Prob(JB):                    8.28e-174
# Kurtosis:                       6.878   Cond. No.                         164.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='3yrAverage Money', y="3yrAverage Migration", data=df)
plt.show()
