# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy
from scipy import stats

# %%
migVSmoney=pd.read_csv("Raw_Data/ThieleMethod/MigrationVSMoney33_continents.csv")
migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Migration Continent
# 0  Afghanistan       1999.0      2.446233e+08          12691.666667      ASIA
# 1  Afghanistan       2000.0      2.410600e+08          12398.333333      ASIA
# 2  Afghanistan       2001.0      2.065400e+08          13536.000000      ASIA
# 3  Afghanistan       2002.0      3.447067e+08          16096.000000      ASIA
# 4  Afghanistan       2003.0      9.037933e+08          17182.000000      ASIA

# %%
migVSmoney=migVSmoney[migVSmoney["3yrAverage Money"]!=0]
migVSmoney=migVSmoney[migVSmoney["3yrAverage Migration"]!=0]

migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Migration Continent
# 0  Afghanistan       1999.0      2.446233e+08          12691.666667      ASIA
# 1  Afghanistan       2000.0      2.410600e+08          12398.333333      ASIA
# 2  Afghanistan       2001.0      2.065400e+08          13536.000000      ASIA
# 3  Afghanistan       2002.0      3.447067e+08          16096.000000      ASIA
# 4  Afghanistan       2003.0      9.037933e+08          17182.000000      ASIA

# %%
migVSmoney=migVSmoney.sort_values(by="3yrAverage Money")
migVSmoney.head()
# Out:
#         Recipient  Report Year  3yrAverage Money  3yrAverage Migration  \
# 2026  Timor-Leste       1999.0      1.020000e+06              0.666667
# 1480        Nauru       1999.0      4.143333e+06              7.333333
# 1481        Nauru       2000.0      5.120000e+06              8.333333
# 1180        Libya       1999.0      5.403333e+06           1214.333333
# 1482        Nauru       2001.0      5.526667e+06              8.333333
#
#      Continent
# 2026      ASIA
# 1480   OCEANIA
# 1481   OCEANIA
# 1180    AFRICA
# 1482   OCEANIA

# %%
#migVSmoney=migVSmoney[migVSmoney["Recipient"]=="Syrian Arab Republic"]

#migVSmoney=migVSmoney[migVSmoney["Report Year"]==2007.0]
migVSmoney.head()
# Out:
#         Recipient  Report Year  3yrAverage Money  3yrAverage Migration  \
# 2026  Timor-Leste       1999.0      1.020000e+06              0.666667
# 1480        Nauru       1999.0      4.143333e+06              7.333333
# 1481        Nauru       2000.0      5.120000e+06              8.333333
# 1180        Libya       1999.0      5.403333e+06           1214.333333
# 1482        Nauru       2001.0      5.526667e+06              8.333333
#
#      Continent
# 2026      ASIA
# 1480   OCEANIA
# 1481   OCEANIA
# 1180    AFRICA
# 1482   OCEANIA

# %%
migVSmoney=migVSmoney.rename(columns={"Average of emigration over all OECD countries":"3yrAverage Migration"})
migVSmoney
# Out:
#                              Recipient  Report Year  3yrAverage Money  \
# 2026                       Timor-Leste       1999.0      1.020000e+06
# 1480                             Nauru       1999.0      4.143333e+06
# 1481                             Nauru       2000.0      5.120000e+06
# 1180                             Libya       1999.0      5.403333e+06
# 1482                             Nauru       2001.0      5.526667e+06
# 1181                             Libya       2000.0      6.090000e+06
# 2133                            Tuvalu       2001.0      8.550000e+06
# 2138                            Tuvalu       2006.0      9.366667e+06
# 1483                             Nauru       2002.0      9.403333e+06
# 666                  Equatorial Guinea       2016.0      9.406667e+06
# 2132                            Tuvalu       2000.0      9.810000e+06
# 2134                            Tuvalu       2002.0      1.003000e+07
# 2131                            Tuvalu       1999.0      1.047000e+07
# 1802                        Seychelles       2009.0      1.048667e+07
# 2137                            Tuvalu       2005.0      1.078333e+07
# 2135                            Tuvalu       2003.0      1.152333e+07
# 1716  Saint Vincent and the Grenadines       2007.0      1.167667e+07
# 665                  Equatorial Guinea       2015.0      1.176667e+07
# 10            14152.333333        ASIA
# 537           11395.333333      AFRICA
# 630           38776.666667      AFRICA
# 17            72410.333333        ASIA
# 951          264952.333333        ASIA
# 1000          45387.000000        ASIA
# 1559          39339.000000      AFRICA
# 16            36523.333333        ASIA
# 11            15225.333333        ASIA
# 15            30567.000000        ASIA
# 12            18820.333333        ASIA
# 14            27881.333333        ASIA
# 13            23271.666667        ASIA
# 1557          37188.333333      AFRICA
# 1558          37863.000000      AFRICA
# 999           40022.333333        ASIA
# 998           33147.666667        ASIA
# 995           19358.000000        ASIA
# 996           21278.666667        ASIA
# 997           26999.333333        ASIA
#
# [2295 rows x 5 columns]

# %%
migVSmoneyQ=migVSmoney.quantile([.05, .95])
migVSmoneyQ
# Out:
#       Report Year  3yrAverage Money  3yrAverage Migration
# 0.05       1999.0      3.148433e+07            103.966667
# 0.95       2016.0      2.566289e+09          77861.733333

# %%
MigrationUPboundary=migVSmoneyQ.iloc[1][2]
MigrationLOWboundary=migVSmoneyQ.iloc[0][2]
MoneyUPboundary=migVSmoneyQ.iloc[1][1]
MoneyLOWboundary=migVSmoneyQ.iloc[0][1]
print(MigrationUPboundary,MigrationLOWboundary)
print(MoneyUPboundary,MoneyLOWboundary)
# Out:
# 77861.7333333 103.966666667
# 2566289000.0 31484333.3333

# %%
df=migVSmoney
len(migVSmoney)
# Out:
# 2295

# %%
migVSmoneyQ = migVSmoney[(migVSmoney["3yrAverage Money"] > MoneyLOWboundary) & (migVSmoney["3yrAverage Money"] < MoneyUPboundary) ]
df = migVSmoneyQ[(migVSmoneyQ["3yrAverage Migration"] > MigrationLOWboundary) & (migVSmoneyQ["3yrAverage Migration"] < MigrationUPboundary)]
len(df)
# Out:
# 1891

# %%
# define the data/predictors as the pre-set feature names  
#df = pd.DataFrame(df, columns=["Average Sum of Money"])

# Put the target (housing value -- MEDV) in another DataFrame
#target = pd.DataFrame(df, columns=["Average of emigration over all OECD countries"])

# %%
#Shapiro-Wilk
x = df['3yrAverage Money']
y = df["3yrAverage Migration"]

shapiro_results = scipy.stats.shapiro(x)

print(shapiro_results)
shapiro_results = scipy.stats.shapiro(y)

print(shapiro_results)
# Out:
# (0.6022007465362549, 0.0)
# (0.5581938624382019, 0.0)

# %%
x = df['3yrAverage Money']
y = df["3yrAverage Migration"]

levene_results = scipy.stats.levene(x,y)

print(levene_results)
# Out:
# LeveneResult(statistic=785.2118891624043, pvalue=1.246113332158517e-159)

# %%
import statsmodels.api as sm

X = df['3yrAverage Money']
y = df["3yrAverage Migration"]

X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     3yrAverage Migration   R-squared:                       0.103
# Model:                              OLS   Adj. R-squared:                  0.103
# Method:                   Least Squares   F-statistic:                     263.1
# Date:                  Thu, 16 Nov 2017   Prob (F-statistic):           4.22e-56
# Time:                          11:34:11   Log-Likelihood:                -27005.
# No. Observations:                  2295   AIC:                         5.401e+04
# Df Residuals:                      2293   BIC:                         5.403e+04
# Df Model:                             1
# Covariance Type:              nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.083e+04    784.716     13.799      0.000    9289.172    1.24e+04
# 3yrAverage Money  1.071e-05    6.6e-07     16.221      0.000    9.41e-06     1.2e-05
# ==============================================================================
# Omnibus:                     1625.057   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23496.047
# Skew:                           3.262   Prob(JB):                         0.00
# Kurtosis:                      17.253   Cond. No.                     1.43e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='3yrAverage Money', y="3yrAverage Migration", data=df)
plt.show()
