# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy
from scipy import stats

# %%
migVSmoney=pd.read_csv("FinalData/MigVsMoney_Cont_Reg31.csv")
migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481
#
#    Emigration per cap over all OECD  Emigration sum over all OECD countries  \
# 0                          0.000716                                 12765.0
# 1                          0.000715                                 13137.0
# 2                          0.000645                                 12173.0
# 3                          0.000613                                 11885.0
# 4                          0.000824                                 16550.0
#
#   Continent        Region
# 0      ASIA  SouthernAsia
# 1      ASIA  SouthernAsia
# 2      ASIA  SouthernAsia
# 3      ASIA  SouthernAsia
# 4      ASIA  SouthernAsia

# %%
uniquecontinents=migVSmoney.Continent.unique()
uniqueregions=migVSmoney.Region.unique()
print(uniquecontinents)
print(uniqueregions)
# Out:
# ['ASIA' 'EUROPE' 'AFRICA' 'AMERICA' 'CARRIBEANS' 'OCEANIA']
# ['SouthernAsia' 'SouthernEurope' 'NorthernAfrica' 'MiddleAfrica'
#  'SouthernAmerica' 'WesternAsia' 'EasternEurope' 'CentralAmerica'
#  'WesternAfrica' 'SouthernAfrica' 'EasternAfrica' 'SouthernEastAsia'
#  'Carribeans' 'EasternAsia' 'Oceania' 'CentralAsia']

# %%
migVSmoneyQ=migVSmoney.quantile([.05, .95])
migVSmoneyQ
# Out:
#       Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0.05       1997.0      3.158933e+07                  4.587187
# 0.95       2015.0      2.357461e+09                383.765456
#
#       Emigration per cap over all OECD  Emigration sum over all OECD countries
# 0.05                          0.000039                                    88.4
# 0.95                          0.009564                                 77839.8

# %%
MigrationUPboundary=migVSmoneyQ.iloc[1][-2]
MigrationLOWboundary=migVSmoneyQ.iloc[0][-2]
MoneyUPboundary=migVSmoneyQ.iloc[1][1]
MoneyLOWboundary=migVSmoneyQ.iloc[0][1]
print(MigrationUPboundary,MigrationLOWboundary)
print(MoneyUPboundary,MoneyLOWboundary)
# Out:
# 0.00956446459566 3.919324473e-05
# 2357460666.67 31589333.3333

# %%
df=migVSmoney
len(migVSmoney)
raw=df

# %%
migVSmoneyQ = migVSmoney[(migVSmoney.ix[:,2] > MoneyLOWboundary) & (migVSmoney.ix[:,2] < MoneyUPboundary) ]
df = migVSmoneyQ[(migVSmoneyQ.ix[:,4] > MigrationLOWboundary) & (migVSmoneyQ.ix[:,4] < MigrationUPboundary)]
len(df)
# Out:
# 2072

# %%
# define the data/predictors as the pre-set feature names  
#df = pd.DataFrame(df, columns=["Average Sum of Money"])

# Put the target (housing value -- MEDV) in another DataFrame
#target = pd.DataFrame(df, columns=["Average of emigration over all OECD countries"])

# %%
raw=df

# %%
#Shapiro-Wilk
x = df.ix[:,2]
y = df.ix[:,4]

shapiro_results = scipy.stats.shapiro(x)

print(shapiro_results)
shapiro_results = scipy.stats.shapiro(y)

print(shapiro_results)
# Out:
# (0.817232608795166, 1.639519203260036e-43)
# (0.7267627716064453, 0.0)

# %%
x = df.ix[:,2]
y = df.ix[:,4]

levene_results = scipy.stats.levene(x,y)

print(levene_results)
# Out:
# LeveneResult(statistic=6015.477636946056, pvalue=0.0)

# %%
import statsmodels.api as sm

X = df.ix[:,2]
Y = df.ix[:,4]

X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.028
# Model:                                          OLS   Adj. R-squared:                  0.028
# Method:                               Least Squares   F-statistic:                     59.86
# Date:                              Thu, 16 Nov 2017   Prob (F-statistic):           1.58e-14
# Time:                                      21:42:33   Log-Likelihood:                 10002.
# No. Observations:                              2072   AIC:                        -2.000e+04
# Df Residuals:                                  2070   BIC:                        -1.999e+04
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0019   6.08e-05     30.736      0.000       0.002       0.002
# 3yrAverage Money -6.579e-13    8.5e-14     -7.737      0.000   -8.25e-13   -4.91e-13
# ==============================================================================
# Omnibus:                      759.373   Durbin-Watson:                   0.309
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2285.102
# Skew:                           1.917   Prob(JB):                         0.00
# Kurtosis:                       6.431   Cond. No.                     1.02e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x=df.ix[:,2], y=df.ix[:,4], data=df)
plt.show()

# %%
migVSmoney=pd.read_csv("FinalData/MigVsMoney_Cont_Reg31.csv")
migVSmoney.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481
#
#    Emigration per cap over all OECD  Emigration sum over all OECD countries  \
# 0                          0.000716                                 12765.0
# 1                          0.000715                                 13137.0
# 2                          0.000645                                 12173.0
# 3                          0.000613                                 11885.0
# 4                          0.000824                                 16550.0
#
#   Continent        Region
# 0      ASIA  SouthernAsia
# 1      ASIA  SouthernAsia
# 2      ASIA  SouthernAsia
# 3      ASIA  SouthernAsia
# 4      ASIA  SouthernAsia

# %%
uniquecontinents=migVSmoney.Continent.unique()
uniqueregions=migVSmoney.Region.unique()
print(uniquecontinents)
print(uniqueregions)
# Out:
# ['ASIA' 'EUROPE' 'AFRICA' 'AMERICA' 'CARRIBEANS' 'OCEANIA']
# ['SouthernAsia' 'SouthernEurope' 'NorthernAfrica' 'MiddleAfrica'
#  'SouthernAmerica' 'WesternAsia' 'EasternEurope' 'CentralAmerica'
#  'WesternAfrica' 'SouthernAfrica' 'EasternAfrica' 'SouthernEastAsia'
#  'Carribeans' 'EasternAsia' 'Oceania' 'CentralAsia']

# %%
df=migVSmoney
len(migVSmoney)
raw=df
print(raw.head())
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481
#
#    Emigration per cap over all OECD  Emigration sum over all OECD countries  \
# 0                          0.000716                                 12765.0
# 1                          0.000715                                 13137.0
# 2                          0.000645                                 12173.0
# 3                          0.000613                                 11885.0
# 4                          0.000824                                 16550.0
#
#   Continent        Region
# 0      ASIA  SouthernAsia
# 1      ASIA  SouthernAsia
# 2      ASIA  SouthernAsia
# 3      ASIA  SouthernAsia
# 4      ASIA  SouthernAsia

# %%
region="SouthernAsia"

# %%
#migVSmoney=migVSmoney[migVSmoney["Report Year"]==2007.0]
for i in uniqueregions:
    region=i
    print(region)
    df=raw[raw["Region"]==region]
    print(len(df))
    migVSmoneyQ=df.quantile([.10, .90])
    MigrationUPboundary=migVSmoneyQ.iloc[1][-2]
    MigrationLOWboundary=migVSmoneyQ.iloc[0][-2]
    MoneyUPboundary=migVSmoneyQ.iloc[1][1]
    MoneyLOWboundary=migVSmoneyQ.iloc[0][1]
    df = df[(df.ix[:,2] > MoneyLOWboundary) & (df.ix[:,2] < MoneyUPboundary) ]
    df = df[(df.ix[:,4] > MigrationLOWboundary) & (df.ix[:,4] < MigrationUPboundary)]
    print(len(df))

    x = df.ix[:,2]
    y = df.ix[:,4]

    shapiro_results = scipy.stats.shapiro(x)

    print("shapiro:",shapiro_results)
    shapiro_results = scipy.stats.shapiro(y)
    print("shapiro:",shapiro_results)

    x = df.ix[:,2]
    y = df.ix[:,4]

    levene_results = scipy.stats.levene(x,y)

    print(levene_results)
    X = df.ix[:,2]
    Y = df.ix[:,4]

    X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

    # Note the difference in argument order
    model = sm.OLS(Y, X).fit()
    predictions = model.predict(X) # make the predictions by the model

    # Print out the statistics
    print(model.summary())
    sns.regplot(x=df.ix[:,2], y=df.ix[:,4], data=df)
    plt.show()
# Out:
# SouthernAsia
# 159
# 98
# shapiro: (0.9196542501449585, 1.6226686057052575e-05)
# shapiro: (0.8690463304519653, 8.115677729847448e-08)
# LeveneResult(statistic=373.40753035520743, pvalue=4.3264866644752444e-47)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.129
# Model:                                          OLS   Adj. R-squared:                  0.120
# Method:                               Least Squares   F-statistic:                     14.24
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           0.000279
# Time:                                      07:16:27   Log-Likelihood:                 641.90
# No. Observations:                                98   AIC:                            -1280.
# Df Residuals:                                    96   BIC:                            -1275.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0007   6.09e-05     11.669      0.000       0.001       0.001
# 3yrAverage Money -1.262e-13   3.35e-14     -3.773      0.000   -1.93e-13   -5.98e-14
# ==============================================================================
# Omnibus:                        8.907   Durbin-Watson:                   0.233
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                9.138
# Skew:                           0.746   Prob(JB):                       0.0104
# Kurtosis:                       3.117   Cond. No.                     3.14e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.14e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# SouthernEurope
# 104
# 65
# shapiro: (0.8713861703872681, 6.797723017371027e-06)
# shapiro: (0.9228493571281433, 0.0005900591495446861)
# LeveneResult(statistic=92.851799310081105, pvalue=7.4153015995567983e-17)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.018
# Model:                                          OLS   Adj. R-squared:                  0.002
# Method:                               Least Squares   F-statistic:                     1.159
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.286
# Time:                                      07:16:28   Log-Likelihood:                 294.92
# No. Observations:                                65   AIC:                            -585.8
# Df Residuals:                                    63   BIC:                            -581.5
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0057      0.001     10.015      0.000       0.005       0.007
# 3yrAverage Money  1.134e-12   1.05e-12      1.077      0.286   -9.71e-13    3.24e-12
# ==============================================================================
# Omnibus:                        7.131   Durbin-Watson:                   0.789
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                7.369
# Skew:                           0.819   Prob(JB):                       0.0251
# Kurtosis:                       2.814   Cond. No.                     9.53e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.53e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# NorthernAfrica
# 113
# 68
# shapiro: (0.8088732957839966, 5.767804012180022e-08)
# shapiro: (0.9008668661117554, 5.320659329299815e-05)
# LeveneResult(statistic=59.976145041104488, pvalue=2.1012561429029213e-12)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.050
# Model:                                          OLS   Adj. R-squared:                  0.036
# Method:                               Least Squares   F-statistic:                     3.470
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):             0.0669
# Time:                                      07:16:28   Log-Likelihood:                 394.45
# No. Observations:                                68   AIC:                            -784.9
# Df Residuals:                                    66   BIC:                            -780.5
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0014      0.000      8.750      0.000       0.001       0.002
# 3yrAverage Money -2.862e-13   1.54e-13     -1.863      0.067   -5.93e-13    2.05e-14
# ==============================================================================
# Omnibus:                        8.095   Durbin-Watson:                   0.372
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                6.005
# Skew:                           0.602   Prob(JB):                       0.0497
# Kurtosis:                       2.182   Cond. No.                     1.79e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.79e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MiddleAfrica
# 180
# 112
# shapiro: (0.8862076997756958, 9.325665217829737e-08)
# shapiro: (0.8439009189605713, 1.6303660643757212e-09)
# LeveneResult(statistic=160.20536638297713, pvalue=5.3048751409437045e-28)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.005
# Model:                                          OLS   Adj. R-squared:                 -0.004
# Method:                               Least Squares   F-statistic:                    0.6032
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.439
# Time:                                      07:16:29   Log-Likelihood:                 702.27
# No. Observations:                               112   AIC:                            -1401.
# Df Residuals:                                   110   BIC:                            -1395.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0006   7.44e-05      7.427      0.000       0.000       0.001
# 3yrAverage Money -1.397e-13    1.8e-13     -0.777      0.439   -4.96e-13    2.17e-13
# ==============================================================================
# Omnibus:                       23.756   Durbin-Watson:                   0.328
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.599
# Skew:                           1.210   Prob(JB):                     2.27e-07
# Kurtosis:                       3.838   Cond. No.                     7.05e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.05e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# SouthernAmerica
# 200
# 124
# shapiro: (0.9096318483352661, 4.406352047681139e-07)
# shapiro: (0.8006986379623413, 1.1039924183164906e-11)
# LeveneResult(statistic=256.40425172611236, pvalue=5.0803354867123629e-40)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.003
# Model:                                          OLS   Adj. R-squared:                 -0.005
# Method:                               Least Squares   F-statistic:                    0.3819
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.538
# Time:                                      07:16:30   Log-Likelihood:                 605.19
# No. Observations:                               124   AIC:                            -1206.
# Df Residuals:                                   122   BIC:                            -1201.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0022      0.000      7.208      0.000       0.002       0.003
# 3yrAverage Money  -4.17e-13   6.75e-13     -0.618      0.538   -1.75e-12    9.19e-13
# ==============================================================================
# Omnibus:                       42.864   Durbin-Watson:                   0.483
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.614
# Skew:                           1.594   Prob(JB):                     2.31e-17
# Kurtosis:                       5.159   Cond. No.                     8.14e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.14e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# WesternAsia
# 180
# 113
# shapiro: (0.8650399446487427, 9.971336645264728e-09)
# shapiro: (0.9235409498214722, 7.0096775743877515e-06)
# LeveneResult(statistic=122.61133812888733, pvalue=5.1752662364789701e-23)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.001
# Model:                                          OLS   Adj. R-squared:                 -0.008
# Method:                               Least Squares   F-statistic:                   0.08994
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.765
# Time:                                      07:16:30   Log-Likelihood:                 634.46
# No. Observations:                               113   AIC:                            -1265.
# Df Residuals:                                   111   BIC:                            -1259.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0014      0.000      8.174      0.000       0.001       0.002
# 3yrAverage Money  7.879e-14   2.63e-13      0.300      0.765   -4.42e-13    5.99e-13
# ==============================================================================
# Omnibus:                       10.292   Durbin-Watson:                   0.327
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.098
# Skew:                           0.676   Prob(JB):                      0.00642
# Kurtosis:                       2.435   Cond. No.                     1.35e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EasternEurope
# 32
# 18
# shapiro: (0.910190999507904, 0.0867031067609787)
# shapiro: (0.9170053005218506, 0.11441124230623245)
# LeveneResult(statistic=46.565069916257109, pvalue=7.4864146653533672e-08)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.385
# Model:                                          OLS   Adj. R-squared:                  0.347
# Method:                               Least Squares   F-statistic:                     10.02
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):            0.00600
# Time:                                      07:16:31   Log-Likelihood:                 94.698
# No. Observations:                                18   AIC:                            -185.4
# Df Residuals:                                    16   BIC:                            -183.6
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0050      0.001      8.058      0.000       0.004       0.006
# 3yrAverage Money -4.343e-12   1.37e-12     -3.166      0.006   -7.25e-12   -1.43e-12
# ==============================================================================
# Omnibus:                        4.701   Durbin-Watson:                   0.847
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                2.358
# Skew:                          -0.752   Prob(JB):                        0.308
# Kurtosis:                       3.941   Cond. No.                     8.99e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.99e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1334: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# CentralAmerica
# 159
# 100
# shapiro: (0.9333308339118958, 7.72970961406827e-05)
# shapiro: (0.7965695858001709, 1.945414107584753e-10)
# LeveneResult(statistic=170.44399940980725, pvalue=1.6483264218006958e-28)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.010
# Model:                                          OLS   Adj. R-squared:                  0.000
# Method:                               Least Squares   F-statistic:                     1.010
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.317
# Time:                                      07:16:31   Log-Likelihood:                 571.64
# No. Observations:                               100   AIC:                            -1139.
# Df Residuals:                                    98   BIC:                            -1134.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0013      0.000      9.043      0.000       0.001       0.002
# 3yrAverage Money  3.183e-13   3.17e-13      1.005      0.317    -3.1e-13    9.47e-13
# ==============================================================================
# Omnibus:                       42.244   Durbin-Watson:                   0.521
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.849
# Skew:                           1.789   Prob(JB):                     2.78e-18
# Kurtosis:                       5.570   Cond. No.                     8.10e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.1e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# WesternAfrica
# 300
# 185
# shapiro: (0.9352818727493286, 2.312201416998505e-07)
# shapiro: (0.8689708113670349, 1.389483927222157e-11)
# LeveneResult(statistic=293.68794698584367, pvalue=8.1180463454983215e-49)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.003
# Model:                                          OLS   Adj. R-squared:                 -0.003
# Method:                               Least Squares   F-statistic:                    0.5298
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.468
# Time:                                      07:16:32   Log-Likelihood:                 1144.0
# No. Observations:                               185   AIC:                            -2284.
# Df Residuals:                                   183   BIC:                            -2277.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0007   7.58e-05      9.344      0.000       0.001       0.001
# 3yrAverage Money -9.296e-14   1.28e-13     -0.728      0.468   -3.45e-13    1.59e-13
# ==============================================================================
# Omnibus:                       43.193   Durbin-Watson:                   0.380
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.385
# Skew:                           1.293   Prob(JB):                     3.84e-15
# Kurtosis:                       4.386   Cond. No.                     1.22e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# SouthernAfrica
# 99
# 61
# shapiro: (0.7767065167427063, 3.074021748261657e-08)
# shapiro: (0.7822583317756653, 4.158327726599964e-08)
# LeveneResult(statistic=46.660533013558606, pvalue=3.7159636820081982e-10)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.504
# Model:                                          OLS   Adj. R-squared:                  0.496
# Method:                               Least Squares   F-statistic:                     59.98
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           1.48e-10
# Time:                                      07:16:32   Log-Likelihood:                 473.37
# No. Observations:                                61   AIC:                            -942.7
# Df Residuals:                                    59   BIC:                            -938.5
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             3.858e-05   2.17e-05      1.776      0.081   -4.88e-06     8.2e-05
# 3yrAverage Money  6.155e-13   7.95e-14      7.745      0.000    4.56e-13    7.75e-13
# ==============================================================================
# Omnibus:                       12.773   Durbin-Watson:                   1.241
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.028
# Skew:                           0.826   Prob(JB):                     0.000331
# Kurtosis:                       4.891   Cond. No.                     4.42e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EasternAfrica
# 339
# 213
# shapiro: (0.9188303351402283, 2.0114581111840835e-09)
# shapiro: (0.6873160600662231, 1.1688081442419888e-19)
# LeveneResult(statistic=335.54883194229149, pvalue=1.2242647993035456e-55)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.203
# Model:                                          OLS   Adj. R-squared:                  0.200
# Method:                               Least Squares   F-statistic:                     53.91
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           4.50e-12
# Time:                                      07:16:33   Log-Likelihood:                 1367.8
# No. Observations:                               213   AIC:                            -2732.
# Df Residuals:                                   211   BIC:                            -2725.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0006   4.59e-05     13.807      0.000       0.001       0.001
# 3yrAverage Money -3.762e-13   5.12e-14     -7.342      0.000   -4.77e-13   -2.75e-13
# ==============================================================================
# Omnibus:                       81.271   Durbin-Watson:                   0.431
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              196.382
# Skew:                           1.775   Prob(JB):                     2.27e-43
# Kurtosis:                       6.087   Cond. No.                     1.52e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# SouthernEastAsia
# 178
# 119
# shapiro: (0.7749311923980713, 3.1844251627971554e-12)
# shapiro: (0.9436046481132507, 8.104720473056659e-05)
# LeveneResult(statistic=75.982440254522373, pvalue=5.1581714739406682e-16)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.000
# Model:                                          OLS   Adj. R-squared:                 -0.009
# Method:                               Least Squares   F-statistic:                 0.0006851
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.979
# Time:                                      07:16:33   Log-Likelihood:                 794.19
# No. Observations:                               119   AIC:                            -1584.
# Df Residuals:                                   117   BIC:                            -1579.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0005   4.46e-05     12.306      0.000       0.000       0.001
# 3yrAverage Money -1.189e-15   4.54e-14     -0.026      0.979   -9.12e-14    8.88e-14
# ==============================================================================
# Omnibus:                       16.943   Durbin-Watson:                   0.556
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.479
# Skew:                           0.882   Prob(JB):                     5.89e-05
# Kurtosis:                       3.903   Cond. No.                     1.55e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Carribeans
# 158
# 102
# shapiro: (0.8474879860877991, 7.476671726180939e-09)
# shapiro: (0.9642607569694519, 0.007348458282649517)
# LeveneResult(statistic=146.92072867573387, pvalue=9.0939681532584364e-26)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.229
# Model:                                          OLS   Adj. R-squared:                  0.222
# Method:                               Least Squares   F-statistic:                     29.77
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           3.54e-07
# Time:                                      07:16:34   Log-Likelihood:                 497.02
# No. Observations:                               102   AIC:                            -990.0
# Df Residuals:                                   100   BIC:                            -984.8
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0076      0.000     26.490      0.000       0.007       0.008
# 3yrAverage Money -1.071e-11   1.96e-12     -5.456      0.000   -1.46e-11   -6.82e-12
# ==============================================================================
# Omnibus:                       13.663   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.001
# Skew:                          -0.244   Prob(JB):                       0.0820
# Kurtosis:                       2.031   Cond. No.                     2.27e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.27e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EasternAsia
# 40
# 26
# shapiro: (0.9363834261894226, 0.11006370931863785)
# shapiro: (0.764392077922821, 4.6275610657176e-05)
# LeveneResult(statistic=33.33375079112632, pvalue=4.9115494696076829e-07)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.379
# Model:                                          OLS   Adj. R-squared:                  0.353
# Method:                               Least Squares   F-statistic:                     14.64
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           0.000818
# Time:                                      07:16:34   Log-Likelihood:                 139.06
# No. Observations:                                26   AIC:                            -274.1
# Df Residuals:                                    24   BIC:                            -271.6
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.0016      0.001     -2.100      0.046      -0.003   -2.75e-05
# 3yrAverage Money  1.259e-11   3.29e-12      3.826      0.001     5.8e-12    1.94e-11
# ==============================================================================
# Omnibus:                        0.097   Durbin-Watson:                   0.646
# Prob(Omnibus):                  0.952   Jarque-Bera (JB):                0.207
# Skew:                           0.126   Prob(JB):                        0.902
# Kurtosis:                       2.643   Cond. No.                     7.48e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.48e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Oceania
# 208
# 142
# shapiro: (0.728032648563385, 6.634210647065699e-15)
# shapiro: (0.8303770422935486, 1.6115163023466827e-11)
# LeveneResult(statistic=69.19885679506568, pvalue=3.8483222737398252e-15)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.130
# Model:                                          OLS   Adj. R-squared:                  0.123
# Method:                               Least Squares   F-statistic:                     20.86
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           1.07e-05
# Time:                                      07:16:35   Log-Likelihood:                 592.90
# No. Observations:                               142   AIC:                            -1182.
# Df Residuals:                                   140   BIC:                            -1176.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0054      0.000     11.282      0.000       0.004       0.006
# 3yrAverage Money -2.029e-11   4.44e-12     -4.568      0.000   -2.91e-11   -1.15e-11
# ==============================================================================
# Omnibus:                       18.223   Durbin-Watson:                   0.253
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.443
# Skew:                           0.753   Prob(JB):                     0.000269
# Kurtosis:                       2.285   Cond. No.                     1.65e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# CentralAsia
# 100
# 66
# shapiro: (0.9666709899902344, 0.0729614868760109)
# shapiro: (0.9013026356697083, 7.033146539470181e-05)
# LeveneResult(statistic=112.74232499909048, pvalue=2.3922514388857123e-19)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.140
# Model:                                          OLS   Adj. R-squared:                  0.127
# Method:                               Least Squares   F-statistic:                     10.44
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):            0.00195
# Time:                                      07:16:35   Log-Likelihood:                 472.25
# No. Observations:                                66   AIC:                            -940.5
# Df Residuals:                                    64   BIC:                            -936.1
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0002   6.12e-05      2.966      0.004    5.92e-05       0.000
# 3yrAverage Money  7.678e-13   2.38e-13      3.230      0.002    2.93e-13    1.24e-12
# ==============================================================================
# Omnibus:                        9.661   Durbin-Watson:                   0.329
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                3.140
# Skew:                          -0.111   Prob(JB):                        0.208
# Kurtosis:                       1.955   Cond. No.                     6.67e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.67e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#migVSmoney=migVSmoney[migVSmoney["Report Year"]==2007.0]
for i in uniquecontinents:
    continent=i
    print(continent)
    df=raw[raw["Continent"]==continent]
    print(len(df))
    migVSmoneyQ=df.quantile([.10, .90])
    MigrationUPboundary=migVSmoneyQ.iloc[1][-2]
    MigrationLOWboundary=migVSmoneyQ.iloc[0][-2]
    MoneyUPboundary=migVSmoneyQ.iloc[1][1]
    MoneyLOWboundary=migVSmoneyQ.iloc[0][1]
    df = df[(df.ix[:,2] > MoneyLOWboundary) & (df.ix[:,2] < MoneyUPboundary) ]
    df = df[(df.ix[:,4] > MigrationLOWboundary) & (df.ix[:,4] < MigrationUPboundary)]
    print(len(df))

    x = df.ix[:,2]
    y = df.ix[:,4]

    shapiro_results = scipy.stats.shapiro(x)

    print("shapiro:",shapiro_results)
    shapiro_results = scipy.stats.shapiro(y)
    print("shapiro:",shapiro_results)

    x = df.ix[:,2]
    y = df.ix[:,4]

    levene_results = scipy.stats.levene(x,y)

    print(levene_results)
    X = df.ix[:,2]
    Y = df.ix[:,4]

    X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

    # Note the difference in argument order
    model = sm.OLS(Y, X).fit()
    predictions = model.predict(X) # make the predictions by the model

    # Print out the statistics
    print(model.summary())
    sns.regplot(x=df.ix[:,2], y=df.ix[:,4], data=df)
    plt.show()
# Out:
# ASIA
# 657
# 427
# shapiro: (0.8043919205665588, 2.378163951058149e-22)
# shapiro: (0.9043045043945312, 9.549194278669622e-16)
# LeveneResult(statistic=324.89130428524749, pvalue=8.8786919619501951e-62)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.000
# Model:                                          OLS   Adj. R-squared:                 -0.002
# Method:                               Least Squares   F-statistic:                 4.834e-05
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.994
# Time:                                      07:15:25   Log-Likelihood:                 2623.3
# No. Observations:                               427   AIC:                            -5243.
# Df Residuals:                                   425   BIC:                            -5234.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0007   3.91e-05     18.634      0.000       0.001       0.001
# 3yrAverage Money  2.863e-16   4.12e-14      0.007      0.994   -8.07e-14    8.12e-14
# ==============================================================================
# Omnibus:                       50.567   Durbin-Watson:                   0.407
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.516
# Skew:                           0.964   Prob(JB):                     3.60e-15
# Kurtosis:                       3.137   Cond. No.                     1.47e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUROPE
# 136
# 89
# shapiro: (0.8708685636520386, 2.8218033776283846e-07)
# shapiro: (0.960501492023468, 0.008377415128052235)
# LeveneResult(statistic=131.79112955495251, pvalue=3.9639643547230665e-23)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.001
# Model:                                          OLS   Adj. R-squared:                 -0.010
# Method:                               Least Squares   F-statistic:                    0.1259
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):              0.724
# Time:                                      07:15:25   Log-Likelihood:                 400.05
# No. Observations:                                89   AIC:                            -796.1
# Df Residuals:                                    87   BIC:                            -791.1
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0053      0.001     10.403      0.000       0.004       0.006
# 3yrAverage Money  3.498e-13   9.86e-13      0.355      0.724   -1.61e-12    2.31e-12
# ==============================================================================
# Omnibus:                        3.766   Durbin-Watson:                   0.920
# Prob(Omnibus):                  0.152   Jarque-Bera (JB):                3.746
# Skew:                           0.469   Prob(JB):                        0.154
# Kurtosis:                       2.637   Cond. No.                     9.02e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.02e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AFRICA
# 1031
# 672
# shapiro: (0.8953019976615906, 5.562880092298609e-21)
# shapiro: (0.8316254019737244, 5.235180487671585e-26)
# LeveneResult(statistic=847.79052228813305, pvalue=7.1670820518994221e-145)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.018
# Model:                                          OLS   Adj. R-squared:                  0.016
# Method:                               Least Squares   F-statistic:                     12.17
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           0.000519
# Time:                                      07:15:26   Log-Likelihood:                 4131.4
# No. Observations:                               672   AIC:                            -8259.
# Df Residuals:                                   670   BIC:                            -8250.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0006   3.37e-05     19.148      0.000       0.001       0.001
# 3yrAverage Money -1.753e-13   5.02e-14     -3.488      0.001   -2.74e-13   -7.66e-14
# ==============================================================================
# Omnibus:                      146.102   Durbin-Watson:                   0.342
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              249.681
# Skew:                           1.353   Prob(JB):                     6.06e-55
# Kurtosis:                       4.265   Cond. No.                     1.13e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AMERICA
# 359
# 229
# shapiro: (0.9107697010040283, 1.7973576793561818e-10)
# shapiro: (0.8477389812469482, 2.988624633686564e-14)
# LeveneResult(statistic=430.33361703088923, pvalue=8.31637438597354e-68)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.014
# Model:                                          OLS   Adj. R-squared:                  0.009
# Method:                               Least Squares   F-statistic:                     3.159
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):             0.0769
# Time:                                      07:15:27   Log-Likelihood:                 1222.5
# No. Observations:                               229   AIC:                            -2441.
# Df Residuals:                                   227   BIC:                            -2434.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0014      0.000     10.760      0.000       0.001       0.002
# 3yrAverage Money  5.409e-13   3.04e-13      1.777      0.077   -5.88e-14    1.14e-12
# ==============================================================================
# Omnibus:                       53.252   Durbin-Watson:                   0.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.099
# Skew:                           1.371   Prob(JB):                     9.02e-19
# Kurtosis:                       4.092   Cond. No.                     7.72e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.72e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# CARRIBEANS
# 158
# 102
# shapiro: (0.8474879860877991, 7.476671726180939e-09)
# shapiro: (0.9642607569694519, 0.007348458282649517)
# LeveneResult(statistic=146.92072867573387, pvalue=9.0939681532584364e-26)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.229
# Model:                                          OLS   Adj. R-squared:                  0.222
# Method:                               Least Squares   F-statistic:                     29.77
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           3.54e-07
# Time:                                      07:15:27   Log-Likelihood:                 497.02
# No. Observations:                               102   AIC:                            -990.0
# Df Residuals:                                   100   BIC:                            -984.8
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0076      0.000     26.490      0.000       0.007       0.008
# 3yrAverage Money -1.071e-11   1.96e-12     -5.456      0.000   -1.46e-11   -6.82e-12
# ==============================================================================
# Omnibus:                       13.663   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.001
# Skew:                          -0.244   Prob(JB):                       0.0820
# Kurtosis:                       2.031   Cond. No.                     2.27e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.27e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# OCEANIA
# 208
# 142
# shapiro: (0.728032648563385, 6.634210647065699e-15)
# shapiro: (0.8303770422935486, 1.6115163023466827e-11)
# LeveneResult(statistic=69.19885679506568, pvalue=3.8483222737398252e-15)
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     Emigration per cap over all OECD   R-squared:                       0.130
# Model:                                          OLS   Adj. R-squared:                  0.123
# Method:                               Least Squares   F-statistic:                     20.86
# Date:                              Fri, 17 Nov 2017   Prob (F-statistic):           1.07e-05
# Time:                                      07:15:28   Log-Likelihood:                 592.90
# No. Observations:                               142   AIC:                            -1182.
# Df Residuals:                                   140   BIC:                            -1176.
# Df Model:                                         1
# Covariance Type:                          nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0054      0.000     11.282      0.000       0.004       0.006
# 3yrAverage Money -2.029e-11   4.44e-12     -4.568      0.000   -2.91e-11   -1.15e-11
# ==============================================================================
# Omnibus:                       18.223   Durbin-Watson:                   0.253
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.443
# Skew:                           0.753   Prob(JB):                     0.000269
# Kurtosis:                       2.285   Cond. No.                     1.65e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
